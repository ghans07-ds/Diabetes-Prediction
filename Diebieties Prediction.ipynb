# %% [markdown]
# # dibiteies prediction

# %% [markdown]
# Diabetes is a condition in which the amount of glucose (sugar) in your blood is too high because
# your body cannot use it properly.
# This happens because your body either cannot use or make a hormone called insulin,
# which is responsible for turning sugar into food for your body's cells

# %% [markdown]
# ### There are two main types of diabetes:

# %% [markdown]
# ## type1:
# where your body is unable to produce any insulin

# %% [markdown]
# # type2:
# where your body either does not produce enough insulin, or cannot use it

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("E://DATA Science//Datasets//Kaggle//pima-indians-diabetes-database//diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.countplot(df['Outcome'])

# %%
def var2hist(df,col,target):
    set1=list(df[df[target]==0][col])
    set2=list(df[df[target]==1][col])
    
    sns.set_style('whitegrid')
    for dataset in (set1,set2):
        sns.distplot(dataset) 
    plt.legend(['0', '1']) 
    plt.xlabel(col)
    plt.ylabel("frequency")

def list2bar(list_ex):
    df1=pd.DataFrame()
    df1['len']=l1
    df1['len'].value_counts().plot.bar()

# %% [markdown]
# # BMI ranges
#
# For most adults, an ideal BMI is in the 18.5 to 24.9 range.
# For children and young people aged 2 to 18, the BMI calculation takes into account age and gender as well as height and weight.   If your BMI is: below 18.5 – you're in the underweight range.

# %%
l1=[]
for i in range(len(df)):
    if df['BMI'][i]>=18.5 and df['BMI'][i]<=24.9:
        l1.append(df['Outcome'][i])

# %%
list2bar(l1)

# %%
var2hist(df,'BMI','Outcome')

# %% [markdown]
# # Glucose

# %% [markdown]
# ### Glucose is a simple sugar with the molecular formula C6H12O6.

# %% [markdown]
# Diabetes is a problem with your body that causes blood sugar (also called blood glucose)
# levels to rise higher than normal. This is also called hyperglycemia

# %% [markdown]
# https://www.healthline.com/nutrition/how-much-sugar-per-day

# %% [markdown]
# # What Is a Safe Amount of Sugar to Eat Per Day?

# %% [markdown]
# Unfortunately, there is no simple answer to this question. Some people can eat a lot of sugar
# without harm, while others should avoid it as much as possible.
#
# According to the American Heart Association (AHA), the maximum amount of added sugars
# you should eat in a day are (7Trusted Source):
#
# Men: 150 calories per day (37.5 grams or 9 teaspoons)
# Women: 100 calories per day (25 grams or 6 teaspoons)

# %%
l1=[]
for i in range(len(df)):
    if df['Glucose'][i]<=100:
        l1.append(df['Outcome'][i])

# %%
list2bar(l1)

# %%
var2hist(df,'Glucose','Outcome')

# %% [markdown]
# # BloodPressure

# %% [markdown]
# ### About 25% of people with Type 1 diabetes and 80% of people with Type 2 diabetes have high blood pressure

# %% [markdown]
# http://www.bloodpressureuk.org/BloodPressureandyou/Yourbody/Diabetes

# %% [markdown]
# ### A blood pressure reading has a top number (systolic) and bottom number (diastolic).

# %% [markdown]
# ### Normal blood pressure is less than 120 over 80 (120/80).

# %%
l1=[]
for i in range(len(df)):
    if df['BloodPressure'][i]>=70 and df['BloodPressure'][i]<=80:
        l1.append(df['Outcome'][i])

# %%
list2bar(l1)

# %%
var2hist(df,'BloodPressure','Outcome')

# %% [markdown]
# # Age

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var2hist(df,'Age','Outcome')

# %%
l1=[]
for i in range(len(df)):
    if df['Age'][i]>=65 and df['Outcome']==1:
        l1.append(df['Outcome'][i])

# %%
l2=[]
for i in range(len(df)):
    if df['Outcome'][i]==1:
        l1.append(df['Age'][i])

# %% [markdown]
# # SkinThickness

# %% [markdown]
# ## Some facts about skin
# Skin is the largest organ of the body.
# It has an area of 2 square metres (22 square feet) in adults, and weighs about 5 kilograms.
# The thickness of skin varies from 0.5mm thick on the eyelids to 4.0mm thick on the heels of your feet.
# Skin is the major barrier between the inside and outside of your body!

# %% [markdown]
# ### tricesps skinfold is tickness between shoulder and elbow
# This feature is basically measurement of triceps skinfold

# %%
var2hist(df,'SkinThickness','Outcome')

# %% [markdown]
# # DiabetesPedigreeFunction
# a function which scores likelihood of diabetes based on family history

# %%
var2hist(df,'DiabetesPedigreeFunction','Outcome')

# %% [markdown]
# # Pregnancies
# Number of times pregnant

# %%
var2hist(df,'Pregnancies','Outcome')

# %% [markdown]
# # Insulin
#  2-Hour serum insulin (mu U/ml)

# %%
var2hist(df,'Insulin','Outcome')

# %%
sns.heatmap(df.corr())

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
plt.subplot(1,3,1)
var2hist(df,'Insulin','Outcome')
plt.subplot(1,3,3)
var2hist(df,'Glucose','Outcome')

# %%
plt.subplot(1,5,1)
var2hist(df,'Pregnancies','Outcome')
plt.subplot(1,5,3)
var2hist(df,'SkinThickness','Outcome')
plt.subplot(1,5,5)
var2hist(df,'Age','Outcome')

# %%
plt.subplot(1,5,1)
var2hist(df,'Insulin','Outcome')
plt.subplot(1,5,3)
var2hist(df,'BMI','Outcome')
